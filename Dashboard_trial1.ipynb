# %%
import warnings
import numpy as pd
import pandas as pd
import pyodbc as odbc
import streamlit as st
import matplotlib.pyplot as plt

# %%
pip install plost
# Out:
# Requirement already satisfied: plost in c:\users\b.aminpour\appdata\local\anaconda3\lib\site-packages (0.2.5)Note: you may need to restart the kernel to use updated packages.

# %%
import plost

# %%
# Defining the Component of Connection String
DRIVER_NAME = "{ODBC Driver 17 for SQL Server}"
SERVER_NAME = "aminpour-lap"
DATABASE_NAME = "order_management"
USERNAME = "DGSERVICE\b.aminpour"

# %%
# Defining the Connection String
connection_string = f"""
    DRIVER={DRIVER_NAME};
    SERVER={SERVER_NAME};
    DATABASE={DATABASE_NAME};
    Trusted_Connection=yes;
"""

# %%
# Making the Connection via Connection String
conn = odbc.connect(connection_string)
cursor = conn.cursor()

# %%
# Returning All the Values from Fields and Records in Desired Table 
query1 = """
    SELECT * 
    FROM order_management.dbo.orders_0101_0505
"""

result = cursor.execute(query1).fetchall()

# %%
# Coverting our Sql Based Table into Pandas Dataframe
df_orders = pd.read_sql(query1, conn)
df_orders.head()
# Out:
#        Id  BasketRef                                    CarrierType  \
# 0  297530  DG-236052                      حضوری - دی جی لند اندرزگو
# 1  297529  DG-236041  حضوری - دی جی لند آنلاین (انبار مرکزی منفی ۷)
# 2  297529  DG-236041  حضوری - دی جی لند آنلاین (انبار مرکزی منفی ۷)
# 3  297528  DG-236040  حضوری - دی جی لند آنلاین (انبار مرکزی منفی ۷)
# 4  297527  DG-236031                 حضوری - دی جی لند بازار موبایل
#
#                                          ProductName ColorName  \
# 0  کابل شارژ یو اس بی به لایتنینگ سیبراتون مدل S4...      سفید
# 1  قلم سامسونگ مدل S Pen EJ-PS908 مناسب برای گوشی...       سبز
# 2              هاب 5 پورت USB-C مک دو دو مدل HU-7750   خاکستری
# 3             هندزفری بلوتوثی کیو سی وای مدل T13 ANC      مشکی
# 4           شارژر سامسونگ مدل EP-TA800NBEGGB اروپایی      مشکی
#
#                                    WarrantyName  Quantity  UnitBasePrice  \
# 0       داده پردازی رایانه متین گارانتی 12 ماهه         1        94000.0
# 1  خدمات ویژه دی‌جی‌لند 7 روز ضمانت بازگشت کالا         1      3090000.0
# 2        داده پرداز رایانه متین گارانتی 12 ماهه         1      1660000.0
# 3                        اتصالات گارانتی 6 ماهه         1       800000.0
# 4                     سریر سرویس گارانتی 6 ماهه         1       600000.0
#
#    UnitNetPrice  UnitDiscount  ...    AutomationCode                 Date  \
# 0       84000.0       10000.0  ...  1050064602114389  1403-04-19 23:43:26
# 1     3090000.0           0.0  ...  1050132071510050  1403-04-19 23:29:36
# 2     1480000.0      180000.0  ...  1011222951005926  1403-04-19 23:29:36
# 3      768000.0       32000.0  ...  1140012643213825  1403-04-19 23:21:28
# 4      515000.0       85000.0  ...  1050042073214122  1403-04-19 23:18:31
#
#       OrderState       Branch              Category        FullName  \
# 0  در حال پردازش  انتخاب نشده           کابل و مبدل       رضا ابرام
# 1  در حال پردازش  انتخاب نشده              قلم لمسی       صدف نوایی
# 2  در حال پردازش  انتخاب نشده  لوازم جانبی کامپیوتر       صدف نوایی
# 3  در حال پردازش  انتخاب نشده       هدفون و هندزفری      محمد مرادی
# 4  در حال پردازش  انتخاب نشده                 شارژر  علیرضا سلیمانی
#
#     PhoneNumber   City Date_Formated  \
# 0  9.115216e+09   None    1403-04-19
# 1  9.389334e+09  تهران    1403-04-19
# 2  9.389334e+09  تهران    1403-04-19
# 3  9.366642e+09  تهران    1403-04-19
# 4  9.193277e+09   None    1403-04-19
#
#                                     ProductNameColor
# 0  کابل شارژ یو اس بی به لایتنینگ سیبراتون مدل S4...
# 1  قلم سامسونگ مدل S Pen EJ-PS908 مناسب برای گوشی...
# 2      هاب 5 پورت USB-C مک دو دو مدل HU-7750-خاکستری
# 3        هندزفری بلوتوثی کیو سی وای مدل T13 ANC-مشکی
# 4      شارژر سامسونگ مدل EP-TA800NBEGGB اروپایی-مشکی
#
# [5 rows x 23 columns]

# %%
# Selecting only required fileds and renaming multywords to solely words title

df = df_orders[['ProductNameColor', 'Date_Formated', 'ColorName',
                'Category', 'WarrantyName', 'Quantity', 'UnitBasePrice',
                'UnitNetPrice', 'UnitDiscount', 'TotalPrice', 'TotalNetPrice', 'TotalDiscount']]

df = df.rename(columns= {'Date_Formated': 'Date', 'ProductNameColor': 'Product', 'ColorName': 'Color', 'WarrantyName': 'Warranty'})

df
# Out:
#                                                  Product        Date    Color  \
# 0      کابل شارژ یو اس بی به لایتنینگ سیبراتون مدل S4...  1403-04-19     سفید
# 1      قلم سامسونگ مدل S Pen EJ-PS908 مناسب برای گوشی...  1403-04-19      سبز
# 2          هاب 5 پورت USB-C مک دو دو مدل HU-7750-خاکستری  1403-04-19  خاکستری
# 3            هندزفری بلوتوثی کیو سی وای مدل T13 ANC-مشکی  1403-04-19     مشکی
# 4          شارژر سامسونگ مدل EP-TA800NBEGGB اروپایی-مشکی  1403-04-19     مشکی
# ...                                                  ...         ...      ...
# 14473  گوشی موبایل سامسونگ مدل Galaxy S23 FE 5G ظرفیت...  1403-04-20  خاکستری
# 14474  گوشی موبایل شیائومی مدل Poco X4 Pro 5G ظرفیت 2...  1403-04-20      آبی
# 14475  محافظ صفحه نمایش مناسب برای گوشی موبایل شیائوم...  1403-04-20   متفرقه
# 14476          شارژر داریا مدل 66 وات مدل DA-P66E05-سفید  1403-04-20     سفید
# 14477  گوشی موبایل سامسونگ مدل Galaxy A05s ظرفیت 128 ...  1403-04-20     مشکی
#
#                    Category                                      Warranty  \
# 0               کابل و مبدل       داده پردازی رایانه متین گارانتی 12 ماهه
# 1                  قلم لمسی  خدمات ویژه دی‌جی‌لند 7 روز ضمانت بازگشت کالا
# 2      لوازم جانبی کامپیوتر        داده پرداز رایانه متین گارانتی 12 ماهه
# 3           هدفون و هندزفری                        اتصالات گارانتی 6 ماهه
# 4                     شارژر                     سریر سرویس گارانتی 6 ماهه
# ...                     ...                                           ...
# 14473           گوشی موبایل  شرکتی معتبر گارانتی 18 ماهه همراه با رجیستری
# 14474           گوشی موبایل  شرکتی معتبر گارانتی 18 ماهه همراه با رجیستری
# 14475     محافظ صفحه‌ نمایش  خدمات ویژه دی‌جی‌لند 7 روز ضمانت بازگشت کالا
# 14476                 شارژر                         داریا گارانتی 18 ماهه
# 14477           گوشی موبایل                   گروه هماهنگ گارانتی 18 ماهه
#
#        Quantity  UnitBasePrice  UnitNetPrice  UnitDiscount  TotalPrice  \
# 0             1        94000.0       84000.0       10000.0     94000.0
# 1             1      3090000.0     3090000.0           0.0   3090000.0
# 2             1      1660000.0     1480000.0      180000.0   1660000.0
# 3             1       800000.0      768000.0       32000.0    800000.0
# 4             1       600000.0      515000.0       85000.0    600000.0
# ...         ...            ...           ...           ...         ...
# 14473         1     26888000.0    26888000.0           0.0  26888000.0
# 14474         1     12399000.0    11399000.0     1000000.0  12399000.0
# 14475         1       130000.0       85000.0       45000.0    130000.0
# 14476         1       380000.0      174000.0      206000.0    380000.0
# 14477         1      6333000.0     6333000.0           0.0   6333000.0
#
#        TotalNetPrice  TotalDiscount
# 0            84000.0        10000.0
# 1          3090000.0            0.0
# 2          1480000.0       180000.0
# 3           768000.0        32000.0
# 4           515000.0        85000.0
# ...              ...            ...
# 14473     26888000.0            0.0
# 14474     11399000.0      1000000.0
# 14475        85000.0        45000.0
# 14476       174000.0       206000.0
# 14477      6333000.0            0.0
#
# [14478 rows x 12 columns]

# %%
# Calculating available metrics (total)
total_quantity = df['Quantity'].sum()
total_discount = df['TotalDiscount'].sum()
total_net = df['TotalNetPrice'].sum()
total_price = df['TotalPrice'].sum()

# %%
# total price and total net price grouped by each category and date

total_price_cd = df.groupby(['Category', 'Date'])['TotalPrice'].sum().reset_index()
total_price_cd = total_price_g.sort_values('Date').reset_index(drop = True)

total_net_cd = df.groupby(['Category', 'Date'])['TotalNetPrice'].sum().reset_index()
total_net_cd = total_net_g.sort_values('Date').reset_index(drop = True)

# %%
total_price_g
total_net_g
# Out:
#                             Category        Date  TotalNetPrice
# 0                               مبدل  1403-01-01       144000.0
# 1                       گوشی موبایل   1403-01-01    656893000.0
# 2                        ساعت هوشمند  1403-01-01     78695000.0
# 3     کامپیوتر همه کاره (all in one)  1403-01-01     31160000.0
# 4                               تبلت  1403-01-01     62747000.0
# ...                              ...         ...            ...
# 1924                         مانیتور  1403-05-05      5240000.0
# 1925                     ساعت هوشمند  1403-05-05     31585000.0
# 1926                     کابل و مبدل  1403-05-05      1944000.0
# 1927                  هارد‌ اکسترنال  1403-05-05     18099000.0
# 1928                        تلویزیون  1403-05-05     45718000.0
#
# [1929 rows x 3 columns]

# %%
# Grouping each catgory by total price and total net price

category_total = df.groupby(['Category']).agg({'TotalPrice': 'sum', 'TotalNetPrice': 'sum'}).reset_index()
category_total = category_total.sort_values('TotalPrice', ascending=False).reset_index(drop=True)

# %%
category_total
# Out:
#                           Category    TotalPrice  TotalNetPrice
# 0                     گوشی موبایل   9.462204e+10   9.389747e+10
# 1                           لپ تاپ  9.246052e+09   9.097809e+09
# 2                      گوشی موبایل  8.890787e+09   8.826549e+09
# 3                      ساعت هوشمند  5.908584e+09   5.650345e+09
# 4                  هدفون و هندزفری  5.080393e+09   4.599210e+09
# 5                           اسپیکر  3.200307e+09   2.998119e+09
# 6                             تبلت  2.334486e+09   2.228699e+09
# 7                       کنسول بازی  1.688452e+09   1.648282e+09
# 8                   هارد‌ اکسترنال  1.628952e+09   1.516000e+09
# 9                         تلویزیون  1.483508e+09   1.342640e+09
# 10                           شارژر  6.895130e+08   5.366300e+08
# 11                       پاور بانک  6.806510e+08   5.607360e+08
# 12                         مانیتور  4.857045e+08   4.780695e+08
# 13                         ساندبار  4.733850e+08   4.418730e+08
# 14                       فلش مموری  4.221550e+08   3.866640e+08
# 15            لوازم جانبی کامپیوتر  4.191828e+08   4.077318e+08
# 16                   هارد اینترنال  3.742550e+08   3.259800e+08
# 17                     کابل و مبدل  1.782050e+08   1.500640e+08
# 18                           یخچال  1.515000e+08   1.440100e+08
# 19  کامپیوتر همه کاره (all in one)  1.192400e+08   1.192400e+08
# 20                      کاور و قاب  1.156120e+08   1.043990e+08
# 21                          کیبورد  1.155750e+08   9.462500e+07
# 22                    گجت های منزل  1.072600e+08   9.011500e+07
# 23                      کارت حافظه  1.027990e+08   9.094100e+07
# 24                            ماوس  1.012030e+08   8.189200e+07
# 25  سایر لوازم جانبی صوتی و تصویری  9.520800e+07   8.196800e+07
# 26               جارو برقی و شارژی  9.201000e+07   8.492900e+07
# 27          لوازم جانبی کنسول بازی  9.132500e+07   8.846900e+07
# 28                 ماشین لباس شویی  5.850000e+07   5.594400e+07
# 29                       کولر گازی  5.600000e+07   5.563000e+07
# 30                   ماشین ظرفشویی  2.960000e+07   2.960000e+07
# 31                              رم  1.513800e+07   1.298700e+07
# 32               محافظ صفحه‌ نمایش  1.415000e+07   1.014700e+07
# 33                            مبدل  1.298000e+07   1.068100e+07
# 34                        قلم لمسی  1.036000e+07   9.615000e+06
# 35          لوازم خانگی و آشپزخانه  9.566160e+06   8.059750e+06
# 36                      لوازم شخصی  4.950000e+06   4.730000e+06
# 37                  پایه نگهدارنده  4.540000e+06   4.168000e+06
# 38                سایر لوازم جانبی  3.880000e+06   3.880000e+06
# 39                     شارژر فندکی  3.790000e+06   3.065000e+06
# 40         لوازم جانبی گوشی موبایل  3.650000e+06   3.650000e+06
# 41                     مودم و روتر  3.550000e+06   3.550000e+06
# 42              تجهیزات ذخیره سازی  3.180000e+06   2.931000e+06
# 43         لوازم جانبی ساعت هوشمند  2.770000e+06   2.115000e+06
# 44                 بند ساعت هوشمند  1.730000e+06   1.386000e+06
# 45                       کارت شبکه  1.600000e+06   1.257000e+06
# 46                             کیس  1.143000e+06   1.143000e+06
# 47                   ماوس و کیبورد  7.500000e+05   7.190000e+05
# 48                       ابزارآلات  6.000000e+05   5.240000e+05
# 49                           سشوار  8.500000e+04   5.900000e+04

# %%
st.title('Order Status Dashboard')
# Out:
# DeltaGenerator()

# %%
c1, c2 = st.columns((7, 3))

# %%
st.set_page_config(layout='wide', initial_sidebar_state='expanded')

with open('Downloads/style.css') as f:
    st.markdown(f'<style>{f.read()}</style>', unsafe_allow_html=True)
    
st.sidebar.header('Dashboard `version 2`')
# Out:
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())
